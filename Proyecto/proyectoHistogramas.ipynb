# %%
import matplotlib.pyplot as plt

# Datos del diccionario
data = {'a': 112, 'u': 57, 'z': 45, 'q': 44, 'i': 43, 't': 42, 'b': 40, 'v': 38, 'w': 38, 'x': 35, 
'l': 32, 'm': 17, 'f': 16, 'o': 14, 'p': 9, 'n': 6, 'e': 5, 'j': 5, 'r': 3, 'd': 1, 'g': 1, 'h': 1, 
'c': 0, 'k': 0, 's': 0, 'y': 0}

# Crear listas para las letras y frecuencias
letras = list(data.keys())
frecuencias = list(data.values())

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(letras, frecuencias, color='salmon')
plt.xlabel('Letra')
plt.ylabel('Frecuencia')
plt.title('Histograma del Texto 1')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos del diccionario
data = {'e': 69, 'x': 61, 'u': 53, 'z': 50, 'g': 35, 'q': 29, 'o': 28, 'a': 27, 'i': 24, 'j': 24, 'l': 22, 
'h': 14, 'n': 14, 't': 14, 'v': 9, 'm': 8, 'r': 6, 'k': 5, 'd': 4, 's': 4, 'c': 2, 'y': 2, 'b': 0, 'f': 0,
 'p': 0, 'w': 0}

# Crear listas para las letras y frecuencias
letras = list(data.keys())
frecuencias = list(data.values())

# Crear el gráfico de barras
plt.figure(figsize=(10,6))
plt.bar(letras, frecuencias, color='red')
plt.xlabel('Letra')
plt.ylabel('Frecuencia')
plt.title('Histograma del Texto 2')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos para el inglés
datos = {
    'Letra': ['E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'L', 'D', 'U', 'C', 'M', 'W', 'Y', 
            'F', 'G', 'P', 'B', 'V', 'K', 'J', 'X', 'Q', 'Z'],
    'Frecuencia': [12.60, 9.37, 8.34, 7.70, 6.80, 6.71, 6.11, 6.11, 5.68, 4.24, 4.14, 2.85, 2.73, 2.53,
             2.34, 2.04, 2.03, 1.92, 1.66, 1.54, 1.06, 0.87, 0.23, 0.20, 0.09, 0.06]
}

# Crear un DataFrame de pandas
df = pd.DataFrame(datos)

# Ordenar el DataFrame por frecuencia descendente
df = df.sort_values(by='Frecuencia', ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(df['Letra'], df['Frecuencia'], color='pink')
plt.xlabel('Letra')
plt.ylabel('Frecuencia (%)')
plt.title('Frecuencia de Letras en Inglés')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico    
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un diccionario con tus datos para el francés
data = {
    'Letra': ['E', 'A', 'S', 'T', 'I', 'R', 'N', 'U', 'L', 'O', 'D', 'M', 'C', 'P', 'É', 'V', 'H', 'G', 'F', 
    'B', 'Q', 'J', 'À', 'X', 'È', 'Ê', 'Z', 'Y', 'K', 'Ô', 'Û', 'W', 'Â', 'Î', 'Ü', 'Ù', 'Ë', 'Œ', 'Ç', 'Ï'],
    'Frecuencia': [15.10, 8.13, 7.91, 7.11, 6.94, 6.43, 6.42, 6.05, 5.68, 5.27, 3.55, 3.23, 3.15, 3.03, 2.13, 1.83, 
                1.08, 0.97, 0.96, 0.93, 0.89, 0.71, 0.54, 0.42, 0.35, 0.24, 0.21, 0.19, 0.16, 0.07, 0.05, 0.04, 0.03, 
                0.03, 0.02, 0.02, 0.01, 0.01, 0.01, 0.01]}

# Crear un DataFrame de pandas
df= pd.DataFrame(data)

# Ordenar el DataFrame por frecuencia descendente
df= df.sort_values(by='Frecuencia', ascending=False)

# Crear el gráfico de barras para francés
plt.figure(figsize=(10, 6))
plt.bar(df['Letra'], df['Frecuencia'], color='green')
plt.xlabel('Letra')
plt.ylabel('Frecuencia (%)')
plt.title('Frecuencia de Letras en Francés')
plt.xticks(rotation=40, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear un diccionario con tus datos
data = {
    'Letra': ['E', 'N', 'I', 'R', 'S', 'T', 'A', 'D', 'H', 'U', 'L', 'C', 'G', 'M', 'O', 'B', 'W', 'F', 
            'K', 'Z', 'V', 'P', 'Ü', 'Ä', 'ß', 'Ö', 'J', 'X', 'Y', 'Q'],
    'Porcentaje': [16.93, 10.53, 8.02, 6.89, 6.42, 5.79, 5.58, 4.98, 4.98, 3.83, 3.60, 3.16, 3.02,
             2.55, 2.24, 1.96, 1.78, 1.49, 1.32, 1.21, 0.84, 0.67, 0.65, 0.54, 0.37, 0.30, 0.24, 0.05, 0.05, 0.02]
}

# Crear un DataFrame de pandas
df = pd.DataFrame(data)

# Ordenar el DataFrame por porcentaje descendente
df = df.sort_values(by='Porcentaje', ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(df['Letra'], df['Porcentaje'], color='blue')
plt.xlabel('Letra')
plt.ylabel('Porcentaje (%)')
plt.title('Frecuencia de Letras en Alemán')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos para el italiano
datos = {
    'Letra': ['E', 'A', 'I', 'O', 'N', 'T', 'R', 'L', 'S', 'C', 'D', 'U', 'P', 'M', 'V', 
            'G', 'H', 'B', 'F', 'Z', 'Q', 'È', 'À', 'Ù', 'Ò', 'Ì', 'É'],
    'Frecuencia': [11.49, 10.85, 10.18, 9.97, 7.02, 6.97, 6.19, 5.70, 5.48, 4.30, 3.39, 3.16,
            2.96, 2.87, 1.75, 1.65, 1.43, 1.05, 1.01, 0.85, 0.45, 0.42, 0.15, 0.12, 0.11, 0.09, 0.06]
}

# Crear un DataFrame de pandas
df = pd.DataFrame(datos)

# Ordenar el DataFrame por frecuencia descendente
df = df.sort_values(by='Frecuencia', ascending=False)

# Crear el gráfico de barras para italiano
plt.figure(figsize=(10, 6))
plt.bar(df['Letra'], df['Frecuencia'], color='orange')
plt.xlabel('Letra')
plt.ylabel('Frecuencia (%)')
plt.title('Frecuencia de Letras en Italiano')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos
datos = {
    'Letra': ['E', 'A', 'O', 'S', 'R', 'I', 'M', 'T', 'N', 'U', 'D', 'C', 'P', 'L', 'V', 'H','Q',
    'G', 'F', 'B', 'Ã', 'É', 'Z', 'Á', 'Ç', 'Ê', 'J', 'X', 'Í', 'Ó', 'K', 'Ú', 'W', 'À', 'Õ', 'Y', 'Â', 'Ô'],
    'Frecuencia': [13.19, 12.21, 10.22, 7.35, 6.73, 5.49, 5.07, 5.07, 5.02, 4.46, 4.21, 3.35, 
    3.01, 3.00, 1.72, 1.22, 1.10, 1.08, 1.07, 1.01, 0.83, 0.52, 0.45, 0.41, 0.40, 0.36, 0.30, 0.28, 
    0.18, 0.17, 0.13, 0.11, 0.05, 0.04, 0.04, 0.04, 0.03, 0.01]
}

# Crear un DataFrame de pandas
df = pd.DataFrame(datos)

# Ordenar el DataFrame por frecuencia descendente
df = df.sort_values(by='Frecuencia', ascending=False)

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(df['Letra'], df['Frecuencia'], color='purple')
plt.xlabel('Letra')
plt.ylabel('Frecuencia (%)')
plt.title('Frecuencia de Letras en portugues')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()
